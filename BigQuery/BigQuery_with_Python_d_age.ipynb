# %% [markdown]
# <a href="https://colab.research.google.com/github/tania-saburova/data_analytics/blob/main/BigQuery_with_Python_d_age.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
project_id = 'crucial-bonsai-377206'

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client(project=project_id)

# %%
client

# %%
row_count = client.query('''
  SELECT
    COUNT(*) as total
  FROM `crucial-bonsai-377206.imbd_dage.d_age`''')

# %%
row_count
# Out:
# QueryJob<project=crucial-bonsai-377206, location=US, id=c0e19f86-7846-4990-91b3-b508368361c5>

# %%
row_count.result()

# %%
for r in row_count.result():
    print(r)
# Out:
# Row((268409,), {'total': 0})

# %%
df = row_count.to_dataframe()

# %%
df
# Out:
#     total
# 0  268409

# %%
d_age = client.query('''
SELECT
    primary_name, d_age, primary_profession, title
FROM
    `crucial-bonsai-377206.imbd_dage.d_age`''')

# %%
d_age
# Out:
# QueryJob<project=crucial-bonsai-377206, location=US, id=0ea64eef-1fc1-4c7d-abbb-8d0027e764e0>

# %%
d_age.result()

# %%
for r in d_age.result():
  print(r)
# Out:
# Streaming output truncated to the last 5000 lines.
# Row(('Mark White', 77, 'actor,archive_footage', 'Dallas'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Tom Ung', 77, 'actor,archive_footage', 'Vaqueiro Detetive'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Chris Borgen', 77, 'actor,archive_footage', 'Manhattan Hero'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Chris Borgen', 77, 'actor,archive_footage', 'Manhattan Hero'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Mark White', 77, 'actor,archive_footage', 'Dallas'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Mark White', 77, 'actor,archive_footage', 'Dallas'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Chris Borgen', 77, 'actor,archive_footage', 'Bohater na wolności'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('David Birkin', 77, 'actor,archive_footage', 'Kung-fu master!'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Mark White', 77, 'actor,archive_footage', 'ダラス'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Helse Achtervolging'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', "L'infernale poursuite"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Aleksandr Martyshkin', 78, 'actor,archive_footage', 'Korolevskaya regata'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Голямото преследване'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Suuri junaryöstö'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'In geheimer Mission'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Los valientes también huyen'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Den store lokomotivjagt'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', "Andrews' Raiders"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Το μεγάλο κυνήγι του τραίνου'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', "La mission d'Andrews"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', "Le 22 spie dell'Unione"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Marea goana feroviara'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Крутой маршрут'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', '機関車大追跡'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Dino Danelli', 78, 'actor,archive_footage', "Rock and Roll Hall of Fame Live: Feelin' Alright"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Polowanie na lokomotywę'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'In geheimer Mission'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Tren Korsanları'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ben Novak', 78, 'actor,archive_footage', 'The World of Whicker'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Héroes de hierro'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Den store lokomotivforfølgelsen'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Aleksandr Martyshkin', 78, 'actor,archive_footage', 'Королевская регата'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Dino Danelli', 78, 'actor,archive_footage', "Rock and Roll Hall of Fame Live: Feelin' Alright"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'O Ataque ao Trem'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('W.S. Sims', 78, 'actor,archive_footage', "The Nation's Peril"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('W.S. Sims', 78, 'actor,archive_footage', "The Nation's Peril"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'In geheimer Mission'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'The Great Locomotive Chase'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Den stora lokomotivjakten'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Perseguição Infernal'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Têmpera de Bravos'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Η μεγάλη καταδίωξη'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Ukradnutý vlak'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('John Wiley', 78, 'actor,archive_footage', 'Los valientes también huyen'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ben Novak', 78, 'actor,archive_footage', 'The World of Whicker'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('
), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Sirkussällskapet'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Monstros'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'La Parade des monstres'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Zrudy'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'A Parada dos Monstros'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Fenómenos'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Barnum'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Spake'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Fenómenos'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'The Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Τα τέρατα'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', "Nature's Mistakes"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks (La parada de los monstruos)'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Dziwolągi'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Nakaze'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'The Monster Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Fenómenos'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Nakaze'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Barnum'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Fenómenos'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks - kummajaiset'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Elizabeth Green', 96, 'actress,archive_footage', 'Freaks'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Margaret Scott', 97, 'actress,archive_footage', 'Nutcracker: The Story of Clara'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Margaret Scott', 97, 'actress,archive_footage', 'Nutcracker: The Story of Clara'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucille Ball Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'Шоу Люси'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'Bei uns zu Haus, da tut sich was'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'El show de Lucy'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'El show de Lucy'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'Hoppla Lucy!'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', "L'extravagante Lucie"), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'O Show da Lucy'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'ザ・ルーシー・ショー'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})
# Row(('Ruth Crews', 98, 'actress,archive_footage', 'The Lucy Show'), {'primary_name': 0, 'd_age': 1, 'primary_profession': 2, 'title': 3})

# %%
d_age_df = d_age.to_dataframe()

# %%
d_age_df
# Out:
#                primary_name  d_age                       primary_profession  \
# 0       Dietrich Bonhoeffer     39  writer,music_department,archive_footage
# 1           Earlyne Schools     25                       actress,soundtrack
# 2             Komel Crowley     28                 producer,archive_footage
# 3              Rexall Chinn     39                       make_up_department
# 4                 Paul Pain     35                       make_up_department
# ...                     ...    ...                                      ...
# 268404           Ruth Crews     98                  actress,archive_footage
# 268405           Ruth Crews     98                  actress,archive_footage
# 268406           Ruth Crews     98                  actress,archive_footage
# 268407           Ruth Crews     98                  actress,archive_footage
# 268408           Ruth Crews     98                  actress,archive_footage
#
#                                                     title
# 0                               Herzlichst, Heinz Rühmann
# 1       Broadway Brevities (1938-1939) #13: The Knight...
# 2                                    Gray State: The Rise
# 3                          Dim Sum: A Little Bit of Heart
# 4                                         Hollywood Flies
# ...                                                   ...
# 268404                                      The Lucy Show
# 268405                                          Lucy Show
# 268406                                         ザ・ルーシー・ショー
# 268407                                      The Lucy Show
# 268408                                      The Lucy Show
#
# [268409 rows x 4 columns]

# %%
d_age_df.head()
# Out:
#           primary_name  d_age                       primary_profession  \
# 0  Dietrich Bonhoeffer     39  writer,music_department,archive_footage
# 1      Earlyne Schools     25                       actress,soundtrack
# 2        Komel Crowley     28                 producer,archive_footage
# 3         Rexall Chinn     39                       make_up_department
# 4            Paul Pain     35                       make_up_department
#
#                                                title
# 0                          Herzlichst, Heinz Rühmann
# 1  Broadway Brevities (1938-1939) #13: The Knight...
# 2                               Gray State: The Rise
# 3                     Dim Sum: A Little Bit of Heart
# 4                                    Hollywood Flies

# %%
d_age_df.tail()
# Out:
#        primary_name  d_age       primary_profession          title
# 268404   Ruth Crews     98  actress,archive_footage  The Lucy Show
# 268405   Ruth Crews     98  actress,archive_footage      Lucy Show
# 268406   Ruth Crews     98  actress,archive_footage     ザ・ルーシー・ショー
# 268407   Ruth Crews     98  actress,archive_footage  The Lucy Show
# 268408   Ruth Crews     98  actress,archive_footage  The Lucy Show

# %%
d_age_df.describe()
# Out:
#            d_age
# count   268409.0
# mean   69.922324
# std    18.677368
# min          0.0
# 25%         59.0
# 50%         73.0
# 75%         84.0
# max        117.0
